# %% [markdown]
# Below, we plot the Bernoulli Polynomials of degree 1 - 5. (*Note that this can script can easily be adapted to visualize Bernoulli Polynomials of different degrees.*)
#
# To this end, we calculate the $ n $th ($ n > 0$) Bernoulli Number **B(n)** using the recursion formula:
# $$
# B_n = -\frac{1}{n+1}\cdot\sum\limits_{k=0}^{n-1}{n+1 \choose k}\cdot B_k
# $$
# with $ B_0 := 1 $. Subsequently, the $ n $th Bernoulli Polynomial evaluated at $ x $ is given as follows:
# $$
# B_n(x) = \sum\limits_{k=0}^n{n \choose k} \cdot B_k \cdot x^{n-k}.
# $$

# %%
import math
import numpy as np
from operator import add
import matplotlib.pyplot as plt


def B(n):
    if n == 0:
        return 1
    elif n == 1:
        return - 0.5
    else:
        s = 0
        for k in range(0,n):
            s += math.comb(n-1, k)* B(k) / (n-k+1)
        s *= n    
        return(s)

def B_poly(n, x):
    s = np.repeat(0,100)
    for k in range(0,n+1):
        s = s + math.comb(n,k)* B(k)* x**(n-k)
    return(s)

x = np.linspace(0,1,100)
for i in range(1,6):
    plt.plot(x, B_poly(i,x), label=r'$B_' + str(i) + '(x)$')
plt.legend()
plt.ylim(-0.2,0.2)
plt.title('Bernoulli polynomial of degree $i = 1,...5$')
# Out:
# Text(0.5, 1.0, 'Bernoulli polynomial of degree $i = 1,...5$')
